# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split 
# %matplotlib inline

# %%
df = pd.read_csv('admission.csv', delimiter=',')
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
y = df['Chance of Admit ']
X = df.drop(['Serial No.','Chance of Admit ','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25) 
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg.predict(X_test)
y_test1=np.array(y_test)
for i in range(len(y_test1)):
    print(y_test1[i],y_pred[i])
reg.score(X,y)
#plt.plot(X,y)
# Out:
# 0.64 0.757841343478177
# 0.63 0.7376520703754701
# 0.5 0.5761378855538148
# 0.49 0.7174627972727632
# 0.86 0.8587877089917115
# 0.93 0.868882345543065
# 0.89 0.8486930724403581
# 0.77 0.6770842510673494
# 0.93 0.8587877089917115
# 0.71 0.8285037993376512
# 0.55 0.646800341413289
# 0.49 0.4953807931429872
# 0.75 0.6770842510673494
# 0.96 0.9496394379538926
# 0.44 0.535759339348401
# 0.62 0.6266110683105821
# 0.72 0.6165164317592287
# 0.8 0.8083145262349443
# 0.8 0.7982198896835908
# 0.77 0.5862325221051683
# 0.85 0.7679359800295305
# 0.82 0.757841343478177
# 0.76 0.8083145262349443
# 0.85 0.7679359800295305
# 0.48 0.6165164317592287
# 0.79 0.7982198896835908
# 0.65 0.5761378855538148
# 0.36 0.5559486124511079
# 0.68 0.7376520703754701
# 0.49 0.5155700662456941
# 0.71 0.7780306165808839
# 0.91 0.8587877089917115
# 0.63 0.5458539758997545
# 0.8 0.8285037993376512
# 0.94 0.8385984358890046
# 0.55 0.8083145262349443
# 0.38 0.5963271586565217
# 0.62 0.6064217952078752
# ...

# %%
print(reg.intercept_)
print(reg.coef_)
# Out:
# -2.472442352954928
# [0.01009464]

# %%
y1 = 0.01009464 * X_test['GRE Score'] -2.472442352954928
plt.plot(np.array(X_test['GRE Score']),y_test1,'o',label='test')
plt.plot(np.array(X_test['GRE Score']),y1,'o',label='yield')
plt.legend()
